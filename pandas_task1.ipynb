# %% [markdown]
# Task questions:
# 1 .Find out there avarage rating on weekly basis keep this in a mind that they take two days of leave
# 2 .Total working days for each agents
# 3. Total query that you hvae taken
# 4. total Feedback that you have received
# 5. a agent name who have average rating between 3.5 to 4
# 6 . Agent name who have rating lesss then 3.5
# 7 . agent name who have rating more then 4.5
# 8 . how many feedaback agents have received more then 4.5 average
# 9 . average weekly response time for each agent
# 10 . average weekely resolution time for each agents
# 11 . list of all agents name
# 12 . percentage of chat on which they have received a feedback
# 13 . Total contributation hour for each and every agents weekly basis
# 14. total percentage of active hour for a month
#
# sunny.savita@ineuron.ai ,sudhanshu@ineuron.ai
#
# deadline of complition of this task is 12 AM IST today
#
# After that if you will submit your task i wont evaluate it at all , excuses will be given to new
# joiners

# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\Dell\ineuron_class_lectures\datasets\AgentPerformance.csv")

# %%
df1=pd.read_csv(r"C:\Users\Dell\ineuron_class_lectures\datasets\AgentLogingReport.csv")

# %%
df.head()
# Out:
#    SL No       Date     Agent Name  Total Chats Average Response Time  \
# 0      1  7/30/2022   Prerna Singh           11               0:00:38
# 1      2  7/30/2022  Nandani Gupta           11               0:01:15
# 2      3  7/30/2022     Ameya Jain           14               0:00:30
# 3      4  7/30/2022  Mahesh Sarade           14               0:01:04
# 4      5  7/30/2022         Swati            14               0:01:11
#
#   Average Resolution Time  Average Rating  Total Feedback
# 0                 0:04:20            4.11               9
# 1                 0:28:25            3.14               7
# 2                 0:11:36            4.55              11
# 3                 0:15:46            4.71               7
# 4                 0:16:33            3.67               6

# %%
df1.head()
# Out:
#    SL No               Agent       Date Login Time Logout Time  Duration
# 0      1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39  02:04:10
# 1      2      Khushboo Priya  30-Jul-22   15:06:59    15:07:16  00:00:17
# 2      3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07  02:26:42
# 3      4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35  00:45:06
# 4      5              Mukesh  30-Jul-22   14:03:15    15:11:52  01:08:36

# %%
df.dtypes
# Out:
# SL No                        int64
# Date                        object
# Agent Name                  object
# Total Chats                  int64
# Average Response Time       object
# Average Resolution Time     object
# Average Rating             float64
# Total Feedback               int64
# dtype: object

# %%
date=pd.to_datetime(df['Date'])

# %%
date
# Out:
# 0      2022-07-30
# 1      2022-07-30
# 2      2022-07-30
# 3      2022-07-30
# 4      2022-07-30
#           ...
# 2155   2022-07-01
# 2156   2022-07-01
# 2157   2022-07-01
# 2158   2022-07-01
# 2159   2022-07-01
# Name: Date, Length: 2160, dtype: datetime64[ns]

# %%
df['date']=date

# %%
df.head()
# Out:
#    SL No       Date     Agent Name  Total Chats Average Response Time  \
# 0      1  7/30/2022   Prerna Singh           11               0:00:38
# 1      2  7/30/2022  Nandani Gupta           11               0:01:15
# 2      3  7/30/2022     Ameya Jain           14               0:00:30
# 3      4  7/30/2022  Mahesh Sarade           14               0:01:04
# 4      5  7/30/2022         Swati            14               0:01:11
#
#   Average Resolution Time  Average Rating  Total Feedback       date
# 0                 0:04:20            4.11               9 2022-07-30
# 1                 0:28:25            3.14               7 2022-07-30
# 2                 0:11:36            4.55              11 2022-07-30
# 3                 0:15:46            4.71               7 2022-07-30
# 4                 0:16:33            3.67               6 2022-07-30

# %%
df['week']=date.dt.isocalendar().week

# %%
df
# Out:
#       SL No       Date          Agent Name  Total Chats Average Response Time  \
# 0         1  7/30/2022        Prerna Singh           11               0:00:38
# 1         2  7/30/2022       Nandani Gupta           11               0:01:15
# 2         3  7/30/2022          Ameya Jain           14               0:00:30
# 3         4  7/30/2022       Mahesh Sarade           14               0:01:04
# 4         5  7/30/2022              Swati            14               0:01:11
# ...     ...        ...                 ...          ...                   ...
# 2155   2156   7/1/2022   Sowmiya Sivakumar            0               0:00:00
# 2156   2157   7/1/2022             Nitin M            0               0:00:00
# 2157   2158   7/1/2022              Vivek             0               0:00:00
# 2158   2159   7/1/2022       Ayushi Mishra            0               0:00:00
# 2159   2160   7/1/2022  Chaitra K Hiremath            0               0:00:00
#
# ...

# %% [markdown]
# # Que 1

# %%
df.groupby(['Agent Name','week'])['Average Rating'].sum()/5 #work 5 days a week
# Out:
# Agent Name  week
# Abhishek    26      0.000
#             27      0.000
#             28      0.000
#             29      0.000
#             30      0.000
#                     ...
# Zeeshan     26      0.000
#             27      1.830
#             28      4.128
#             29      4.452
#             30      3.312
# Name: Average Rating, Length: 350, dtype: float64

# %% [markdown]
# # Que2

# %%
resp_time=pd.to_timedelta(df['Average Response Time'])

# %%
df['resp_time']=pd.to_timedelta(df['Average Response Time'])

# %%
type(resp_time[0])
# Out:
# pandas._libs.tslibs.timedeltas.Timedelta

# %%
resp_time[0:3]
# Out:
# 0   0 days 00:00:38
# 1   0 days 00:01:15
# 2   0 days 00:00:30
# Name: Average Response Time, dtype: timedelta64[ns]

# %%
reso_time=pd.to_timedelta(df['Average Resolution Time'])

# %%
df['reso_time']=pd.to_timedelta(df['Average Resolution Time'])

# %%
conv='00:00:00'

# %%
pd.to_timedelta(conv)
# Out:
# Timedelta('0 days 00:00:00')

# %%
(df.groupby(['Agent Name']))['resp_time'].value_counts()
# Out:
# Agent Name     resp_time
# Abhishek       0 days 00:00:00    30
# Aditya         0 days 00:00:00    30
# Aditya Shinde  0 days 00:00:00    18
#                0 days 00:01:26     2
#                0 days 00:00:42     1
#                                   ..
# Zeeshan        0 days 00:01:48     1
#                0 days 00:01:53     1
#                0 days 00:03:16     1
#                0 days 00:03:42     1
#                0 days 00:03:49     1
# Name: resp_time, Length: 718, dtype: int64

# %%
df['working_day']=""

# %%
for i in range(len(df['SL No'])):
    if df['resp_time'][i]!=pd.to_timedelta(conv):
        df['working_day'][i]=1
    else:
        df['working_day'][i]=0
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_11648\945174685.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['working_day'][i]=1
# C:\Users\Dell\AppData\Local\Temp\ipykernel_11648\945174685.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['working_day'][i]=0

# %%
df.groupby('Agent Name')['working_day'].sum()
# Out:
# Agent Name
# Abhishek          0
# Aditya            0
# Aditya Shinde    12
# Aditya_iot       17
# Amersh            0
#                  ..
# Uday Mishra       0
# Vasanth P         0
# Vivek             5
# Wasim            16
# Zeeshan          16
# Name: working_day, Length: 70, dtype: object

# %%
df.columns
# Out:
# Index(['SL No', 'Date', 'Agent Name', 'Total Chats', 'Average Response Time',
#        'Average Resolution Time', 'Average Rating', 'Total Feedback', 'date',
#        'week', 'resp_time', 'reso_time', 'working_day'],
#       dtype='object')

# %%
df.head()
# Out:
#    SL No       Date     Agent Name  Total Chats Average Response Time  \
# 0      1  7/30/2022   Prerna Singh           11               0:00:38
# 1      2  7/30/2022  Nandani Gupta           11               0:01:15
# 2      3  7/30/2022     Ameya Jain           14               0:00:30
# 3      4  7/30/2022  Mahesh Sarade           14               0:01:04
# 4      5  7/30/2022         Swati            14               0:01:11
#
#   Average Resolution Time  Average Rating  Total Feedback       date  week  \
# 0                 0:04:20            4.11               9 2022-07-30    30
# 1                 0:28:25            3.14               7 2022-07-30    30
# 2                 0:11:36            4.55              11 2022-07-30    30
# 3                 0:15:46            4.71               7 2022-07-30    30
# 4                 0:16:33            3.67               6 2022-07-30    30
#
#         resp_time       reso_time working_day
# 0 0 days 00:00:38 0 days 00:04:20           1
# ...

# %% [markdown]
# # Que3

# %%
df.groupby('Agent Name')['Total Chats'].sum()
# Out:
# Agent Name
# Abhishek           0
# Aditya             0
# Aditya Shinde    277
# Aditya_iot       231
# Amersh             0
#                 ...
# Uday Mishra        0
# Vasanth P          0
# Vivek             44
# Wasim            433
# Zeeshan          542
# Name: Total Chats, Length: 70, dtype: int64

# %% [markdown]
# # Que4

# %%
df.groupby('Agent Name')['Total Feedback'].sum()
# Out:
# Agent Name
# Abhishek           0
# Aditya             0
# Aditya Shinde    153
# Aditya_iot       131
# Amersh             0
#                 ...
# Uday Mishra        0
# Vasanth P          0
# Vivek             20
# Wasim            284
# Zeeshan          335
# Name: Total Feedback, Length: 70, dtype: int64

# %% [markdown]
# # Que5 a agent name who have average rating between 3.5 to 4

# %%
def rating_avg(a):
    if a>=3.5 and a<=4:
        return 'm'
    else:
        return 'l/h'

# %%
df['rating_between_range']=df['Average Rating'].apply(rating_avg)

# %%
df[df['rating_between_range']=='m'][['Agent Name','Average Rating']]
# Out:
#                Agent Name  Average Rating
# 4                  Swati             3.67
# 10           Manjunatha A            3.60
# 73    Boktiar Ahmed Bappy            4.00
# 76          Prateek _iot             3.75
# 78          Nandani Gupta            3.79
# ...                   ...             ...
# 1941       Jawala Prakash            3.80
# 2018        Sanjeev Kumar            4.00
# 2021        Aditya Shinde            3.54
# 2023     Deepranjan Gupta            3.71
# 2097        Sanjeev Kumar            4.00
#
# [114 rows x 2 columns]

# %% [markdown]
# # Que 6

# %%
df[df['Average Rating']<3.5]['Agent Name']
# Out:
# 1            Nandani Gupta
# 19        Hitesh Choudhary
# 20              Sanjeevan
# 21                Anirudh
# 22        Shiva Srivastava
#                ...
# 2155     Sowmiya Sivakumar
# 2156               Nitin M
# 2157                Vivek
# 2158         Ayushi Mishra
# 2159    Chaitra K Hiremath
# Name: Agent Name, Length: 1474, dtype: object

# %% [markdown]
# # Que7

# %%
df[df['Average Rating']>4.5]['Agent Name']
# Out:
# 2               Ameya Jain
# 3            Mahesh Sarade
# 5                  Mukesh
# 6          Saikumarreddy N
# 7            Sanjeev Kumar
#                ...
# 2100        Shubham Sharma
# 2101         Jaydeep Dixit
# 2102    Shivananda Sonwane
# 2103        Khushboo Priya
# 2104       Hrisikesh Neogi
# Name: Agent Name, Length: 307, dtype: object

# %% [markdown]
# # Que8

# %%
df[df['Average Rating']>4.5].groupby('Agent Name')['Total Feedback'].sum()
# Out:
# Agent Name
# Aditya Shinde              73
# Aditya_iot                 43
# Ameya Jain                150
# Anirudh                     2
# Ankitjha                    1
# Aravind                   178
# Ayushi Mishra              75
# Bharath                   231
# Boktiar Ahmed Bappy        52
# Chaitra K Hiremath          5
# Deepranjan Gupta           83
# Harikrishnan Shaji         80
# Hrisikesh Neogi           183
# Ishawant Kumar             79
# Jawala Prakash             33
# Jayant Kumar                7
# Jaydeep Dixit             179
# Khushboo Priya            134
# Madhulika G                67
# Mahesh Sarade              46
# Maitry                     81
# Manjunatha A              132
# Mithun S                   93
# Mukesh                     17
# Mukesh Rao                  1
# Muskan Garg                14
# Nandani Gupta              91
# Nishtha Jain               18
# Prabir Kumar Satapathy     53
# Prateek _iot               54
# ...

# %% [markdown]
# # Que9

# %%
df.groupby(['Agent Name','week'])['resp_time'].mean()
# Out:
# Agent Name  week
# Abhishek    26               0 days 00:00:00
#             27               0 days 00:00:00
#             28               0 days 00:00:00
#             29               0 days 00:00:00
#             30               0 days 00:00:00
#                               ...
# Zeeshan     26               0 days 00:00:00
#             27     0 days 00:00:23.571428571
#             28     0 days 00:02:03.428571428
#             29     0 days 00:01:02.857142857
#             30     0 days 00:01:03.833333333
# Name: resp_time, Length: 350, dtype: timedelta64[ns]

# %% [markdown]
# # Que10

# %%
df.groupby(['Agent Name','week'])['reso_time'].mean()
# Out:
# Agent Name  week
# Abhishek    26               0 days 00:00:00
#             27               0 days 00:00:00
#             28               0 days 00:00:00
#             29               0 days 00:00:00
#             30               0 days 00:00:00
#                               ...
# Zeeshan     26               0 days 00:00:00
#             27               0 days 00:05:23
#             28     0 days 00:16:24.285714285
#             29     0 days 00:13:14.285714285
#             30        0 days 00:12:53.500000
# Name: reso_time, Length: 350, dtype: timedelta64[ns]

# %% [markdown]
# # Que11

# %%
list(df['Agent Name'].unique())
# Out:
# ['Prerna Singh',
#  'Nandani Gupta',
#  'Ameya Jain',
#  'Mahesh Sarade',
#  'Swati ',
#  'Mukesh ',
#  'Saikumarreddy N',
#  'Sanjeev Kumar',
#  'Shubham Sharma',
#  'Nishtha Jain',
#  'Manjunatha A',
#  'Khushboo Priya',
#  'Suraj S Bilgi',
#  'Harikrishnan Shaji',
#  'Hrisikesh Neogi',
#  'Shivan K',
#  'Sowmiya Sivakumar',
#  'Madhulika G',
#  'Mithun S',
#  'Hitesh Choudhary',
#  'Sanjeevan ',
#  'Anirudh ',
#  'Shiva Srivastava',
#  'Dibyanshu ',
#  'Ashish ',
#  'Uday Mishra',
#  'Aditya Shinde',
#  'Jayant Kumar',
#  'Aditya_iot ',
#  'Prabir Kumar Satapathy',
#  'Saurabh Shukla',
#  'Wasim ',
#  'Samprit ',
#  'Maitry ',
#  'Abhishek ',
#  'Rishav Dash',
#  'Aravind ',
#  'Tarun ',
#  'Muskan Garg',
#  'Ankit Sharma',
#  'Bharath ',
#  'Ashad Nasim',
#  'Vasanth P',
#  'Aditya ',
#  'Amersh ',
#  'Sandipan Saha',
#  'Ineuron Intelligence ',
#  'Mahak ',
#  'Mukesh Rao ',
#  'Zeeshan ',
#  'Anurag Tiwari',
#  'Ankitjha ',
#  'Saif Khan',
#  'Jaydeep Dixit',
# ...

# %% [markdown]
# # Que 12 percentage of chat on which they have received a feedback

# %%
df.dtypes
# Out:
# SL No                                int64
# Date                                object
# Agent Name                          object
# Total Chats                          int64
# Average Response Time               object
# Average Resolution Time             object
# Average Rating                     float64
# Total Feedback                       int64
# date                        datetime64[ns]
# week                                 int64
# resp_time                  timedelta64[ns]
# reso_time                  timedelta64[ns]
# working_day                         object
# dtype: object

# %%
df['percentage_chat']=(df['Total Chats']/df['Total Chats'].sum())*100

# %%
df.head()
# Out:
#    SL No       Date     Agent Name  Total Chats Average Response Time  \
# 0      1  7/30/2022   Prerna Singh           11               0:00:38
# 1      2  7/30/2022  Nandani Gupta           11               0:01:15
# 2      3  7/30/2022     Ameya Jain           14               0:00:30
# 3      4  7/30/2022  Mahesh Sarade           14               0:01:04
# 4      5  7/30/2022         Swati            14               0:01:11
#
#   Average Resolution Time  Average Rating  Total Feedback       date  week  \
# 0                 0:04:20            4.11               9 2022-07-30    30
# 1                 0:28:25            3.14               7 2022-07-30    30
# 2                 0:11:36            4.55              11 2022-07-30    30
# 3                 0:15:46            4.71               7 2022-07-30    30
# 4                 0:16:33            3.67               6 2022-07-30    30
#
#         resp_time       reso_time working_day  percentage  percentage-chat  \
# ...

# %%
df[df['Total Feedback']!=0][['Agent Name','percentage_chat']]
# Out:
#               Agent Name  percentage_chat
# 0           Prerna Singh         0.074728
# 1          Nandani Gupta         0.074728
# 2             Ameya Jain         0.095109
# 3          Mahesh Sarade         0.095109
# 4                 Swati          0.095109
# ...                  ...              ...
# 2101       Jaydeep Dixit         0.169837
# 2102  Shivananda Sonwane         0.156250
# 2103      Khushboo Priya         0.163043
# 2104     Hrisikesh Neogi         0.101902
# 2105              Tarun          0.149457
#
# [731 rows x 2 columns]

# %% [markdown]
# # Que13 Total contribution hour for each and every agents weekly basis

# %%
df1.head()
# Out:
#    SL No               Agent       Date Login Time Logout Time  Duration
# 0      1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39  02:04:10
# 1      2      Khushboo Priya  30-Jul-22   15:06:59    15:07:16  00:00:17
# 2      3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07  02:26:42
# 3      4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35  00:45:06
# 4      5              Mukesh  30-Jul-22   14:03:15    15:11:52  01:08:36

# %%
df1.dtypes
# Out:
# SL No           int64
# Agent          object
# Date           object
# Login Time     object
# Logout Time    object
# Duration       object
# dtype: object

# %%
df1['date']=pd.to_datetime(df1['Date'])

# %%
df1['converted_duration']=pd.to_timedelta(df1['Duration'])

# %%
df1['weeks']=pd.to_datetime(df1['Date']).dt.isocalendar().week

# %%
df1
# Out:
#      SL No               Agent       Date Login Time Logout Time   Duration  \
# 0        1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39   02:04:10
# 1        2      Khushboo Priya  30-Jul-22   15:06:59    15:07:16   00:00:17
# 2        3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07   02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35   00:45:06
# 4        5              Mukesh  30-Jul-22   14:03:15    15:11:52   01:08:36
# ..     ...                 ...        ...        ...         ...        ...
# 995    996        Manjunatha A  20-Jul-22   09:03:51    15:02:28   05:58:37
# 996    997             Bharath  20-Jul-22   09:00:49    15:01:32   06:00:43
# 997    998      Khushboo Priya  20-Jul-22   08:59:20    14:26:55   05:27:34
# 998    999        Nishtha Jain  20-Jul-22   08:43:55    14:00:33   05:16:38
# 999   1000               Tarun  01-Jul-22   01:52:47    12:01:07  514:08:20
#
# ...

# %%
df1.groupby(['Agent','weeks'])['converted_duration'].sum()
# Out:
# Agent          weeks
# Aditya Shinde  30       0 days 00:02:10
# Aditya_iot     29       0 days 06:05:43
#                30       0 days 09:38:09
# Amersh         30       0 days 03:03:50
# Ameya Jain     29       1 days 00:04:59
#                              ...
# Tarun          26      21 days 10:08:20
# Wasim          29       0 days 19:37:32
#                30       1 days 04:33:13
# Zeeshan        29       1 days 00:25:39
#                30       1 days 00:39:40
# Name: converted_duration, Length: 89, dtype: timedelta64[ns]

# %% [markdown]
# # Que 14. total percentage of active hour for a month

# %%
df1['percentage_hour']=(df1['converted_duration']/df1['converted_duration'].sum())*100

# %%
df1['months']=pd.to_datetime(df1['Date']).dt.month

# %%
df1
# Out:
#      SL No               Agent       Date Login Time Logout Time   Duration  \
# 0        1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39   02:04:10
# 1        2      Khushboo Priya  30-Jul-22   15:06:59    15:07:16   00:00:17
# 2        3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07   02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35   00:45:06
# 4        5              Mukesh  30-Jul-22   14:03:15    15:11:52   01:08:36
# ..     ...                 ...        ...        ...         ...        ...
# 995    996        Manjunatha A  20-Jul-22   09:03:51    15:02:28   05:58:37
# 996    997             Bharath  20-Jul-22   09:00:49    15:01:32   06:00:43
# 997    998      Khushboo Priya  20-Jul-22   08:59:20    14:26:55   05:27:34
# 998    999        Nishtha Jain  20-Jul-22   08:43:55    14:00:33   05:16:38
# 999   1000               Tarun  01-Jul-22   01:52:47    12:01:07  514:08:20
#
# ...

# %%
df1.groupby('Agent')['percentage_hour'].sum()
# Out:
# Agent
# Aditya Shinde              0.001657
# Aditya_iot                 0.721622
# Amersh                     0.140548
# Ameya Jain                 1.930103
# Ankitjha                   0.103990
# Anurag Tiwari              0.127474
# Aravind                    1.114659
# Ayushi Mishra              1.748729
# Bharath                    2.205388
# Boktiar Ahmed Bappy        1.847214
# Chaitra K Hiremath         1.574592
# Deepranjan Gupta           4.875092
# Dibyanshu                  2.412692
# Harikrishnan Shaji         2.464018
# Hrisikesh Neogi            2.640805
# Hyder Abbas                0.017801
# Ineuron Intelligence       0.066451
# Ishawant Kumar             2.375217
# Jawala Prakash             2.128577
# Jaydeep Dixit              2.745024
# Khushboo Priya             1.998134
# Madhulika G                2.112891
# Mahesh Sarade              1.968929
# Maitry                     1.419519
# Manjunatha A               1.893367
# Mithun S                   2.072218
# ...
